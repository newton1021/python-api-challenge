# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
gkey = "AIzaSyAhWbU_3GVnSb7OozY4WWqsYeI_3Lz78nE"
wkey = "91cf1cf7f676df148d7d2bd8539ffe38"

# %%
def get_weather(lat, lng):
    weather_url = f'http://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lng}&appid={wkey}&units=imperial'
    response = requests.get(weather_url).json()
    return response

# %%
def get_URL(cityname):
    result = ('https://maps.googleapis.com/maps/api/geocode/json?address={0}&key={1}').format(cityname, gkey)
    return result

# %% [markdown]
# ## Generate Cities List

# %%
from citipy import citipy as ct
import random as r
import matplotlib.pyplot as plt
import numpy as np
import json
import requests
import pandas as pd

from scipy import stats as st

# %%
city_file = "../output_data/city_list.csv"

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
temp_cities = {""}
idx = 0

# %%
numCities = 500

act_city = []
act_lat = []
act_lng = []
act_state = []
act_country = []

idx = 0


while idx < 500:
    
    looking = True
    while looking:
        x = r.random() * 140 - 60 
        y = r.random() * 300 - 130
        c = ct.nearest_city(x,y)
        
        cc = c.city_name + '_' + c.country_code
        
        if cc not in temp_cities:
            temp_cities = temp_cities.union([cc])
            looking = False
            print(idx, cc)

    url = get_URL(c.city_name)
    try:
        result = requests.get(url).json()['results'][0]
    except: 
        print (f'could not find {c.city_name}')
        continue
        
    location = result['geometry']['location']
    act_lat.append(location['lat'])
    act_lng.append(location['lng'])

    state = ""
    country = ""

    try:
        city = result['address_components'][0]['long_name']
        for add_idx in range(1,len(result['address_components'])):
            if result['address_components'][add_idx]['types'][0] == 'country':
                country = result['address_components'][add_idx]['long_name']
            elif result['address_components'][add_idx]['types'][0] == 'administrative_area_level_1': 
                state = result['address_components'][add_idx]['long_name']

        print(f'{city}, {state}, {country}, {y:0.3f} => {act_lng[idx]:0.3f} longitude  {x:0.3f} => {act_lat[idx]:0.3f} latitude')

        act_city.append(city)
        act_state.append(state)
        act_country.append(country)

    except:
        print(f"Error {idx}")
        break
    idx += 1
# Out:
# 0 alice_us
# 6th floor, New York, United States, -98.750 => -73.992 longitude  27.782 => 40.745 latitude
# 1 chokurdakh_ru
# Chokurdakh, Sakha Republic, Russia, 150.785 => 147.916 longitude  70.133 => 70.622 latitude
# 2 rikitea_pf
# Rikitea, The Tuamotu and Gambier Islands, French Polynesia, -125.769 => -134.969 longitude  -55.375 => -23.122 latitude
# 3 hasaki_jp
# 210, New York, United States, 155.978 => -73.989 longitude  25.177 => 40.730 latitude
# 4 saint george_bm
# 425, Alabama, United States, -54.615 => -86.818 longitude  34.923 => 33.491 latitude
# 5 pochutla_mx
# San Pedro Pochutla, Oaxaca, Mexico, -97.807 => -96.467 longitude  8.535 => 15.749 latitude
# 6 turukhansk_ru
# Turukhansk, Krasnoyarsk Krai, Russia, 88.269 => 87.962 longitude  63.301 => 65.796 latitude
# 7 gurgan_az
# Gorgan, Golestan Province, Iran, 51.289 => 54.439 longitude  39.038 => 36.846 latitude
# 8 acapulco_mx
# Acapulco, Guerrero, Mexico, -102.046 => -99.824 longitude  12.494 => 16.853 latitude
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"city":act_city,
                       "state": act_state,
                       "country": act_country,
                       "latitude": act_lat,
                       "longitude": act_lng})

city_df = city_df.drop_duplicates().reset_index(drop = True)

city_df.to_csv("../output_data/city_list.csv")

# %%
#look up the weather data for each city
temps = []
humid = []
clouds = []
wind_speed = []
temp_max = []

for idx, row in city_df.iterrows():
    lat = row['latitude']
    long = row['longitude']
    
    x = get_weather(lat, long)
    temps.append(x['main']['temp'])
    humid.append(x['main']['humidity'])
    clouds.append(x['clouds']['all'])
    wind_speed.append(x['wind']['speed'])
    temp_max.append(x['main']['temp_max'])
    
city_df['humidity'] = humid
city_df['temp'] = temps
city_df['temp_max'] = temp_max
city_df['clouds'] = clouds
city_df['wind'] = wind_speed

# %%
city_df
# Out:
#               city                            state           country  \
# 0        6th floor                         New York     United States
# 1       Chokurdakh                   Sakha Republic            Russia
# 2          Rikitea  The Tuamotu and Gambier Islands  French Polynesia
# 3              210                         New York     United States
# 4              425                          Alabama     United States
# ..             ...                              ...               ...
# 494  Garh Mahārāja                           Punjab          Pakistan
# 495        Stawell                         Victoria         Australia
# 496      Mutsamudu                           Nzwani           Comoros
# 497       Ivanivka                    Odessa Oblast           Ukraine
# 498      Omsukchan                   Magadan Oblast            Russia
#
#       latitude   longitude  humidity   temp  temp_max  clouds   wind
# ...

# %%
plt.scatter(city_df['longitude'], city_df['latitude'])

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

test100 = [x <= 100 for x in city_df['humidity']]
city_df_100 = city_df[test100]

# %%
city_df_100
# Out:
#               city                            state           country  \
# 0        6th floor                         New York     United States
# 1       Chokurdakh                   Sakha Republic            Russia
# 2          Rikitea  The Tuamotu and Gambier Islands  French Polynesia
# 3              210                         New York     United States
# 4              425                          Alabama     United States
# ..             ...                              ...               ...
# 494  Garh Mahārāja                           Punjab          Pakistan
# 495        Stawell                         Victoria         Australia
# 496      Mutsamudu                           Nzwani           Comoros
# 497       Ivanivka                    Odessa Oblast           Ukraine
# 498      Omsukchan                   Magadan Oblast            Russia
#
#       latitude   longitude  humidity   temp  temp_max  clouds   wind
# ...

# %%
city_df_100.to_csv("../output_data/city_list_100.csv")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
latitude_x = city_df_100['latitude']
temperture = city_df_100['temp']

# %%
plt.scatter(latitude_x, temperture)

plt.title('Temperture vs Latitude',color='Red', size=15)
plt.ylabel("Temperture")
plt.xlabel('Latidude')

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
humidity = city_df_100['humidity']

# %%
plt.scatter(latitude_x, humidity)

plt.title('Humidity vs Latitude',color='Red', size=15)
plt.ylabel("Humidity")
plt.xlabel('Latidude')
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
cloudy = city_df_100['clouds']

# %%
plt.scatter(latitude_x, cloudy)
plt.title('Cloudiness vs Latitude',color='Red', size=15)
plt.ylabel("Cloudiness")
plt.xlabel('Latidude')

plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
windspeed = city_df_100['wind']

# %%
plt.scatter(latitude_x, windspeed)
plt.title('Wind Speed vs Latitude',color='Red', size=15)
plt.ylabel("Wind Speed")
plt.xlabel('Latidude')
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north = city_df_100[city_df_100['latitude'] >=0]
south = city_df_100[city_df_100['latitude'] <0]

# %%
n_lat = north['latitude']
s_lat = abs(south['latitude'])

# %%
n_maxtemp = north['temp_max']
s_maxtemp = south['temp_max']

# %%
(slope_n, intercept_n, pvalue_n, rvalue_n, sterr_n) = st.linregress(n_lat,n_maxtemp) 
n_x = range(0,90,5)
n_y = slope_n * n_x + intercept_n

# %%
plt.scatter(n_lat, n_maxtemp)
plt.plot(n_x, n_y, marker = "" , color = 'g')
plt.grid(True)
plt.xlabel('Latitude (North)')
plt.ylabel('Max Temperture (F)')
plt.title('Max Temp in Northern Hemisphere',size=14,color = 'purple')
plt.xlim(0,90)
plt.ylim(0,120)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
(slope_s, intercept_s, pvalue_s, rvalue_s, sterr_s) = st.linregress(s_lat,s_maxtemp) 
s_x = range(0,90,5)
s_y = slope_s * s_x + intercept_s

# %%
plt.scatter(s_lat, s_maxtemp)
plt.plot(s_x, s_y, marker = "" , color = 'red')
plt.grid(True)
plt.xlabel('Latitude (South)')
plt.ylabel('Max Temperture (F)')
plt.title('Max Temp in Southern Hemisphere',size=14,color = 'blue')
plt.xlim(0,90)
plt.ylim(0,120)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_humidity = north['humidity']
s_humidity = south['humidity']

# %%
(slope_n, intercept_n, pvalue_n, rvalue_n, sterr_n) = st.linregress(n_lat,n_humidity) 
n_x = range(0,90,5)
n_y = slope_n * n_x + intercept_n

# %%
plt.scatter(n_lat, n_humidity)
plt.plot(n_x, n_y, marker = "" , color = 'g')
plt.grid(True)
plt.xlabel('Latitude (North)')
plt.ylabel('Humidity (%)')
plt.title('Humidity in Northern Hemisphere',size=14,color = 'purple')
plt.xlim(0,90)
plt.ylim(0,100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
(slope_s, intercept_s, pvalue_s, rvalue_s, sterr_s) = st.linregress(s_lat,s_humidity) 
s_x = range(0,90,5)
s_y = slope_s * s_x + intercept_s

# %%
plt.scatter(s_lat, s_humidity)
plt.plot(s_x, s_y, marker = "" , color = 'red')
plt.grid(True)
plt.xlabel('Latitude (South)')
plt.ylabel('Humidity (%)')
plt.title('Humidity in Southern Hemisphere',size=14,color = 'blue')
plt.xlim(0,90)
plt.ylim(0,100)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_clouds = north['clouds']
s_clouds = south['clouds']

# %%
(slope_n, intercept_n, pvalue_n, rvalue_n, sterr_n) = st.linregress(n_lat,n_clouds) 
n_x = range(0,90,5)
n_y = slope_n * n_x + intercept_n

# %%
plt.scatter(n_lat, n_clouds)
plt.plot(n_x, n_y, marker = "" , color = 'g')
plt.grid(True)
plt.xlabel('Latitude (North)')
plt.ylabel('Cloud Cover (%)')
plt.title('Cloud Cover in Northern Hemisphere',size=14,color = 'purple')
plt.xlim(0,90)
plt.ylim(0,100)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
(slope_s, intercept_s, pvalue_s, rvalue_s, sterr_s) = st.linregress(s_lat,s_clouds) 
s_x = range(0,90,5)
s_y = slope_s * s_x + intercept_s

# %%
plt.scatter(s_lat, s_clouds)
plt.plot(s_x, s_y, marker = "" , color = 'red')
plt.grid(True)
plt.xlabel('Latitude (South)')
plt.ylabel('Cloud Cover (%)')
plt.title('Cloud Cover in Southern Hemisphere',size=14,color = 'blue')
plt.xlim(0,90)
plt.ylim(0,100)
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_wind = north['wind']
s_wind = south['wind']

# %%
(slope_n, intercept_n, pvalue_n, rvalue_n, sterr_n) = st.linregress(n_lat,n_wind) 
n_x = range(0,90,5)
n_y = slope_n * n_x + intercept_n

# %%
plt.scatter(n_lat, n_wind)
plt.plot(n_x, n_y, marker = "" , color = 'g')
plt.grid(True)
plt.xlabel('Latitude (North)')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed in Northern Hemisphere',size=14,color = 'purple')
plt.xlim(0,90)
plt.ylim(0,40)
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
(slope_s, intercept_s, pvalue_s, rvalue_s, sterr_s) = st.linregress(s_lat,s_wind) 
s_x = range(0,90,5)
s_y = slope_s * s_x + intercept_s

# %%
plt.scatter(s_lat, s_wind)
plt.plot(s_x, s_y, marker = "" , color = 'red')
plt.grid(True)
plt.xlabel('Latitude (South)')
plt.ylabel('Wind Speed (MPH)')
plt.title('Wind Speed in Southern Hemisphere',size=14,color = 'blue')
plt.xlim(0,90)
plt.ylim(0,40)
plt.show()

# %% [markdown]
# ## Summary
#
# ### Latitude and Weather
# From the above data we can see that some weather conditions are affected by latitude and other are not.
#
# 1. 'the largest correlation is found with temperture. The farther you are from the equator (north or south) the cooler your temperture gets.
# 2. Cloud cover has very little correlation with latitude. The plot is scattered from 0% to 100% regardless of the latitude
#
#
# ### Other observations
#
# in randomly selecting latitude and longitude positions it was difficult to find a city. There is more water over the earth than there is land. I tried to miss the artics and the Pacific ocean. by limiting my random point range. but I still hit water on many tries.
