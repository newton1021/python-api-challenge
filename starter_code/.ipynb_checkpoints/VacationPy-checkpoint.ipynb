# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
g_key = "AIzaSyAhWbU_3GVnSb7OozY4WWqsYeI_3Lz78nE"

city_weather_file = "../output_data/city_list_100.csv"

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# # Import API key
# from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
city_df = pd.read_csv(city_weather_file)
len(city_df)
# Out:
# 499

# %%
city_df.head()
# Out:
#    Unnamed: 0        city                            state           country  \
# 0           0   6th floor                         New York     United States
# 1           1  Chokurdakh                   Sakha Republic            Russia
# 2           2     Rikitea  The Tuamotu and Gambier Islands  French Polynesia
# 3           3         210                         New York     United States
# 4           4         425                          Alabama     United States
#
#     latitude   longitude  humidity   temp  temp_max  clouds   wind
# 0  40.745487  -73.991685        21  58.05     61.00       1   8.21
# 1  70.622169  147.916168        82  25.61     25.61       7   4.79
# 2 -23.122303 -134.969154        78  76.32     76.32      95  11.39
# 3  40.729700  -73.988813        33  57.92     61.00       1  10.36
# 4  33.490975  -86.818366        55  61.43     63.00      75   3.29

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = city_df[["latitude", "longitude"]].astype(float)

# Humidity to float and store

humidity_data = city_df['humidity'].astype(float)

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity_data, 
                                 dissipating=False, max_intensity=100,
                                 point_radius =2)

# %%
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
max_temp = 90
min_temp = 75
max_wind = 10
max_cloud = 25

test = [(city_df.temp_max < max_temp) & 
        (city_df.temp_max > min_temp) & 
        (city_df.wind <= max_wind) & 
        (city_df.clouds <= max_cloud)]

# %%
ideal_df = city_df[test[0]]

# %%
len(ideal_df)
# Out:
# 42

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
def findHotel(lat, lng):
    params = {
              "location":f"{lat},{lng}",
             "radius": "5000",
              "type": "lodging",
             "key": g_key}
    params['fields'] = 'geometry,name,formatted_address'
    try:
        url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?'
        response = requests.get(url, params).json()['results'][0]
    except:
        print(f"Not found: {url}")
        response = '{}'
    return response

# %%
ideal_df.loc[:,'Hotel'] = ''
ideal_df.loc[:,'Hotel_Lat'] = 0
ideal_df.loc[:,'Hotel_lng'] = 0

for i,x in ideal_df.iterrows():
    hotel = findHotel(x['latitude'], x['longitude'])
    try:
        ideal_df.loc[i,'Hotel'] = hotel['name']
        ideal_df.loc[i,'Hotel_Lat'] = hotel['geometry']['location']['lat']
        ideal_df.loc[i,'Hotel_lng'] = hotel['geometry']['location']['lng']
    except:
        continue
# Out:
# Not found: https://maps.googleapis.com/maps/api/place/nearbysearch/json?
# Not found: https://maps.googleapis.com/maps/api/place/nearbysearch/json?
# Not found: https://maps.googleapis.com/maps/api/place/nearbysearch/json?

# %%
ideal_df = ideal_df[ideal_df['Hotel'] != ""]

# %%
ideal_df = ideal_df.reset_index(drop=True)
ideal_df
# Out:
#     Unnamed: 0                city  \
# 0           18      Saint-Philippe
# 1           20           El Fuerte
# 2           25          Port Blair
# 3           53               Adrar
# 4           62      Cap Malheureux
# 5           67              Broome
# 6           78            Mucurapo
# 7           81              Atuona
# 8          106              Riyadh
# 9          117           Alirajpur
# 10         151     Puerto Colombia
# 11         200          Amalapuram
# 12         214            Cam Ranh
# 13         257        Port Hedland
# 14         258  Qiongshan District
# 15         262      Samarai Island
# 16         263             Bubaque
# 17         266             Yomitan
# 18         271              Nabire
# 19         297               Qeshm
# 20         317         Broken Hill
# 21         324              Yarada
# 22         338           Martapura
# 23         353        Yunhe County
# 24         360             Labutta
# 25         365                Jalu
# 26         370          Hambantota
# 27         382     Wencheng County
# 28         410              Namibe
# 29         427                 119
# 30         428            Cabedelo
# 31         429             Gouyave
# 32         431            Ajdabiya
# 33         437       Alice Springs
# 34         439         Grand Gaube
# 35         455              Pyapon
# 36         483             Umm Bab
# 37         487       Kota Kinabalu
# 38         496           Mutsamudu
#
#                                                 state              country  \
# 0                                        Saint-Pierre              Réunion
# 1                                             Sinaloa               Mexico
# 2                         Andaman and Nicobar Islands                India
# 3                                      Adrar Province              Algeria
# 4                         Rivière du Rempart District            Mauritius
# 5                                   Western Australia            Australia
# 6                           Port of Spain Corporation  Trinidad and Tobago
# 7                                   Marquesas Islands     French Polynesia
# 8                                     Riyadh Province         Saudi Arabia
# 9                                      Madhya Pradesh                India
# 10                                          Atlantico             Colombia
# 11                                     Andhra Pradesh                India
# 12                                 Khanh Hoa Province              Vietnam
# 13                                  Western Australia            Australia
# 14                                             Hainan                China
# 15                                                NaN     Papua New Guinea
# 16                                             Bolama        Guinea-Bissau
# 17                                            Okinawa                Japan
# 18                                              Papua            Indonesia
# 19                                                NaN                 Iran
# 20                                    New South Wales            Australia
# 21                                     Andhra Pradesh                India
# 22                                   South Kalimantan            Indonesia
# 23                                           Zhejiang                China
# 24                                         Ayeyarwady      Myanmar (Burma)
# 25                                  Al Wahat District                Libya
# 26                                  Southern Province            Sri Lanka
# 27                                           Zhejiang                China
# 28                                    Namibe Province               Angola
# 29                                          Minnesota        United States
# 30                                   State of Paraíba               Brazil
# 31                                         Saint John              Grenada
# 32                                           Ajdabiya                Libya
# 33                                 Northern Territory            Australia
# 34                        Rivière du Rempart District            Mauritius
# 35                                         Ayeyarwady      Myanmar (Burma)
# 36  الريان, Al Rayyan, Ар Раян, Αρ Ραϊάν, אראיאן, ...                Qatar
# 37                                              Sabah             Malaysia
# 38                                             Nzwani              Comoros
#
#      latitude   longitude  humidity   temp  temp_max  clouds  wind  \
# 0  -21.303576   55.735613        64  70.57     75.20       0  9.22
# 1   26.417632 -108.614594        32  80.73     80.73       4  3.74
# 2   11.623377   92.726483        69  85.12     85.12      14  7.92
# 3   28.017440   -0.264250        29  75.20     75.20       0  9.22
# 4  -19.986874   57.612742        89  75.99     75.99      12  3.00
# 5  -17.964429  122.230366        37  87.80     87.80       1  5.75
# 6   10.669339  -61.532582        83  76.80     78.01      20  7.18
# 7   -9.802860 -139.039807        68  80.35     80.35       8  7.45
# 8   24.713552   46.675296        18  74.86     77.00       0  3.94
# 9   22.305971   74.355815        30  88.27     88.27      13  5.53
# 10  11.001004  -74.950761        83  80.60     80.60      20  8.05
# 11  16.577480   82.003146        74  86.00     86.00      20  3.44
# 12  11.966212  109.191558        55  89.60     89.60      20  5.75
# 13 -20.311031  118.609454        70  86.00     86.00       5  8.05
# 14  20.003169  110.353972        70  87.80     87.80      20  6.71
# 15 -10.612023  150.664076        80  80.62     80.62      16  9.48
# 16  11.298738  -15.837837        83  75.20     75.20       0  1.14
# 17  26.396077  127.744412        47  78.89     80.60      20  5.75
# 18  -3.372225  135.501625        59  88.03     88.03      15  4.05
# 19  26.811867   55.891321        69  78.80     78.80       0  3.15
# 20 -31.959586  141.460814        26  80.60     80.60       0  5.75
# 21  17.663100   83.278028        66  85.21     85.21       0  8.16
# 22  -3.411598  114.845200        55  89.60     89.60      20  2.30
# 23  28.115790  119.573397        49  83.75     83.75       1  4.50
# 24  16.149328   94.756216        52  89.56     89.56       6  3.42
# 25  29.040621   21.499133        15  82.89     82.89       0  8.30
# 26   6.142883   81.121231        94  82.40     82.40      20  2.30
# 27  27.786996  120.091498        48  81.00     81.00       0  4.05
# 28 -15.197832   12.157554        79  76.08     76.08       4  1.54
# 29  44.984002  -93.270084        28  71.46     77.00       1  5.75
# 30  -7.040262  -34.843010        94  75.20     75.20      20  5.75
# 31  12.169174  -61.726142        83  78.80     78.80      20  9.22
# 32  30.214647   20.140259        13  83.17     83.17       4  9.55
# 33 -23.698042  133.880747        20  84.20     84.20      19  8.05
# 34 -20.014212   57.669408        89  75.99     75.99      14  3.00
# 35  16.285033   95.679982        53  89.58     89.58       5  2.08
# 36  25.209150   50.801190        94  76.35     82.99       1  3.15
# 37   5.980408  116.073457        79  89.31     89.60      20  4.61
# 38 -12.169581   44.400470        82  78.94     78.94      21  8.12
#
#                                                 Hotel  Hotel_Lat   Hotel_lng
# 0                         Abri du Cratère de Takamaka -21.307102   55.762374
# 1                                     Hotel Rio Vista  26.423171 -108.620827
# 2                          Lalbagh Ecofriendly Resort  11.622902   92.719315
# 3                                       hotel mraguen  28.004184   -0.278002
# 4                      Veranda Grand Baie Hotel & Spa -20.008416   57.578803
# 5                                      Mangrove Hotel -17.960097  122.242489
# 6                 Courtyard by Marriott Port of Spain  10.659757  -61.534322
# 7                                         Villa Enata  -9.795229 -139.030526
# 8                            ibis Riyadh Olaya Street  24.711981   46.676870
# 9                              Alirajpur cabs service  22.305971   74.355815
# 10                                 Hotel El Emigrante  10.988012  -74.960098
# 11                    swayamprabha service apartments  16.585554   82.007007
# 12  Alma Resort - Timeshare Vacation Ownership - L...  11.999728  109.209288
# 13                     Discovery Parks - Port Hedland -20.310183  118.638324
# 14                                Sun City Restaurant  20.038580  110.336415
# 15                                          Nuli Sapi -10.625897  150.645083
# 16                                 Casa Dora, Bubaque  11.301724  -15.838214
# 17                                Hotel Nikko Alivila  26.415018  127.715529
# 18                                     Mahavira Hotel  -3.373230  135.509918
# 19                                     هتل سنتی ایناس  26.811867   55.891321
# 20                               Royal Exchange Hotel -31.957779  141.465727
# 21                                             Jeevan  17.681809   83.262000
# 22                              Montana Hotel Syariah  -3.443744  114.833067
# 23               Huangcheng Yunhe International Hotel  28.112926  119.582522
# 24                         Cipin Goverment Guesthouse  16.150914   94.756858
# 25                                 البيت الوظيفي جالو  29.040631   21.499136
# 26                                        Bungalow 63   6.130587   81.125130
# 27                             Sunlight Holiday Hotel  27.786021  120.098602
# 28                             Hotel Chik Chik Namibe -15.197832   12.157554
# 29           Renaissance Minneapolis Hotel, The Depot  44.980164  -93.263288
# 30                                        Union Motel  -7.039409  -34.851418
# 31                                    Rumboat Retreat  12.146106  -61.734708
# 32                         مسعود امغيب بومويس المغربي  30.214647   20.140259
# 33                         Desert Palms Alice Springs -23.713395  133.879820
# 34               Veranda Paul et Virginie Hotel & Spa -20.006569   57.668077
# 35                               Aung Naing Thu Motel  16.291974   95.680907
# 36                                         mike beach  25.219002   50.764406
# 37                                  Gaya Centre Hotel   5.986650  116.076419
# 38                                       Medina Hotel -12.166970   44.394472

# %%
hotel_list = ideal_df['Hotel'].tolist()
hotel_location = ideal_df[['Hotel_Lat', 'Hotel_lng']].astype(float)

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.symbol_layer(hotel_location, fill_color='rgba(100,0,200,0.4)', stroke_color='rgba(0,0,200,0.6)' ,
                                info_box_content=[f'Hotel: {hotel}' for hotel in hotel_list])


fig.add_layer(hotel_layer)

fig
# Display figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Thoughts
#
# There are many places to travel that would be ideal! Even Minnesota today!
